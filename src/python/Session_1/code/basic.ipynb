# %%
# x = 4

# print("welcome to DEPI",hex(id(x)))#print id of var

# %%
x = 20
y = 30

print("this is x value = ", x, "and y value is  =  ", y)
print("this is x {0}   and  y {1}".format("george", y))
print(f"this is x = {x}   and  y = {y}")
# Out:
# this is x value =  20 and y value is  =   30
# this is x george   and  y 30
# this is x = 20   and  y = 30

# %%
name  = "ArithmeticError"
course_name = " "
id = ""
print(f"")

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
name = "Depi R4"
name[0:4:2]
# Out:
# 'Dp'

# %%
name = "welcome into depi r4"
upper_txt = name.upper()
print(upper_txt)
# Out:
# WELCOME INTO DEPI R4

# %%
lower_txt = upper_txt.lower()
lower_txt
# Out:
# 'welcome into depi r4'

# %%
name = "welcome into depi r4 r4"
list_1 = name.split()
# print(type(list_1))
list_1
# Out:
# ['welcome', 'into', 'depi', 'r4', 'r4']

# %%
sent =' '.join(list_1)
type(sent)
# Out:
# str

# %%
sent.endswith("welcome")
# Out:
# False

# %%
print("welcome into\b \"our\" group")
# Out:
# welcome int "our" group

# %%
x = 5,5
list(x)
# Out:
# [5, 5]

# %%
x =(1,2,3)
x[0] = "depi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 x =(1,2,3)
# ----> 2 x[0] = "depi"
#
# TypeError: 'tuple' object does not support item assignment

# %%
x ="depi"
tuple(x)


str
# Out:
# ('d', 'e', 'p', 'i')

# %%
def user_info(x,y):
    """
    param_1 : take first number from user
    type:param_1:  int 
    param_2 : take second number from user 
    type_param_2: int
    
    return: sum two number 
    type_return: int
    
    
    """
    return f"num_1 is {x}, num2 is {y} = ", x+y

# %%
print("my name {}".format("george"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 user_info()
#
# TypeError: user_info() missing 2 required positional arguments: 'x' and 'y'

# %%
def get_info(name ="amit", age = 30):
    
    return f"my name is {name} and my age {age}"

# %%
get_info()
# Out:
# 'my name is amit and my age 30'

# %%
def std_info(name , age ):
    
    return name, age

# %%
lambda x : x+10
# Out:
# <function __main__.<lambda>(x)>

# %%
fun_1 =lambda x : x+10
type(fun_1)
# fun_1(10)
# Out:
# function

# %%
def info():
    return f"hello"

# %%
info
# Out:
# <function __main__.info()>

# %%
list_1 = [1,2,3,"depi","learning",True,[1,2,3,"true",['ds','ml','genai']]]

# %%
list_1[6][4][2] ="Agentic AI"

# %%
list_one = ["DEPI","Learning","ml"]
list_one.append("dl")

# %%
list_one.insert(0,"genAI")

# %%
list_one
# Out:
# ['genAI', 'DEPI', 'Learning', 'ml', 'dl']

# %%
list_1= [1,2,3]
list_2 =[4,5,6]
x = list_1 + list_2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_1.extend(list_2)

# %%
list_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_one = ["DEPI","Learning","learning","ml"]
x = list_one.remove("DEPI")
print(x)
# Out:
# None

# %%
list_one = ["DEPI","Learning","learning","ml"]
x = list_one.pop(0)
print(x)
# Out:
# DEPI

# %%
list_one = ["DEPI","Learning","learning","ml"]
del list_one
print(list_one)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 list_one = ["DEPI","Learning","learning","ml"]
#       2 del list_one
# ----> 3 print(list_one)
#
# NameError: name 'list_one' is not defined

# %%
name  = input("enter your name ")
id = input("enter your id ")

print(f"your name is{name}, and your id is {id}")
# Out:
# your name isgeorge, and your id is 4444

# %%
list_2 = ["depi","learning","ml"]
item = input("enter your value")
list_2.remove(item)
print(f"output list ={ list_2}")
# Out:
# output list =['learning', 'ml']

# %%
list_3 =[20,10,4,2,50]
list_3.sort()

# %%
list_3
# Out:
# [2, 4, 10, 20, 50]

# %%
tuple_1 =(20,10,4,2,50)
# tuple_1[0] = 50
list(tuple_1)
# Out:
# [20, 10, 4, 2, 50]

# %%
set_1 = {1,2,3}
set_2 = {3,4,5}
set_1.difference(set_2)
# Out:
# {1, 2}

# %%
dict_1 = {"key_1":12.5,"key2":"DEPI"}
dict_1["key_1"] = 50
dict_1
# Out:
# {'key_1': 50, 'key2': 'DEPI'}

# %%
items = [('a',1),('b',2),('c',3)]
dict_new = dict(items)
print(dict_new)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num=int( input("enter your value"))
type(num)
# Out:
# int

# %%
5/2
# Out:
# 2.5

# %%
2 >= 2
# Out:
# True

# %%
a =3
b = 5

a is not b
# Out:
# True

# %%
a  = 200
b  = 33

if b > a :
    print("b is greater than a ")
elif a == b:
    print("a and b are equal")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = -5
y = 10
if (x > 0 or  y > 0)  and :
    print("both x and  y are positive.")
# Out:
# both x and  y are positive.

# %%
x = 5
result = "Even" if x % 2 == 0 else "odd"
print(result)
# Out:
# odd

# %%
a = 10 
b = 5
result = a + b if a>b else a-b

print(result)
# Out:
# 15

# %%
score  = int(input("Enter your score"))

if 0<     score  <=100:
    if  90 <=    score     <=  100:
        print("A")
    elif 
    
    
    
    
else:

# %%
for i in range(10):
    print(i,"ml")
else:
    print("finished")
# Out:
# 0 ml
# 1 ml
# 2 ml
# 3 ml
# 4 ml
# 5 ml
# 6 ml
# 7 ml
# 8 ml
# 9 ml
# finished

# %%
for i in range(6):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
if x > 3 :
    pass

# %%
x = 6 
while x>0:
    print("hello")
    x -=1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
